# %% [markdown]
# ## Startup Instructions ###
#
# Must connect locally to Cloud SQL Auth proxy before this notebook can run.
# Instructions for downloading proxy found [here](https://cloud.google.com/sql/docs/postgres/quickstart-proxy-test#install-proxy)
#
# Start the proxy in its own terminal so you can monitor its output. Replace <INSTANCE_CONNECTION_NAME> with the instance connection name you copied in the previous step. Replace <PORT> with '5432' for postgres, or '1433' postgres port already in use.
# ```
# ./cloud_sql_proxy -instances=<INSTANCE_CONNECTION_NAME>=tcp:<PORT>
# ```
# Example for current database connection:
# ```
# ./cloud_sql_proxy -instances=plenary-era-308716:us-central1:denver-real-estate=tcp:1433 \
# -credential_file=<PATH TO CREDENTIAL FILE> &
# ```
# A message similar to the following appears:
# ```
# Listening on 127.0.0.1:5432 for myproject:us-central1:myinstance".
# Ready for new connections
# ```

# %%
import sqlalchemy, os
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, Text, String, Boolean, Float, DateTime
from sqlalchemy.dialects.postgresql import JSON, JSONB
import pandas as pd

# %% [markdown]
# The following assumes 'SQL_CLOUD_USER' and 'SQL_CLOUD_PASS' are already saved as environmental variables. Please email me at Olivia.a.Carnes@gmail.com to request credentials.

# %%
user = os.environ['SQL_CLOUD_USER']
password = os.environ['SQL_CLOUD_PASS']

# %%
engine = sqlalchemy.create_engine("postgresql://{}:{}@127.0.0.1:1433/postgres".format(user, password))
connection = engine.connect()
metadata = sqlalchemy.MetaData()
metadata.reflect(bind=engine)

# %% [markdown]
# Currently available tables include
# * 'listings_query': all listings and some facts
# * 'listings_detailed': all listings and detailed facts
# * 'building_query': building info for apartments

# %%
df = pd.read_sql_table('listings_detailed', connection)

# %%
df.sort_values(by=['zpid'])
# Out:
#              zpid                  DateAdded               DateModified  \
# 9710     13292327 2021-04-09 21:02:25.269311 2021-04-09 21:02:25.269342
# 9856     13292367 2021-04-09 21:10:28.188232 2021-04-09 21:10:28.188254
# 9855     13292376 2021-04-09 21:10:26.768474 2021-04-09 21:10:26.768496
# 10543    13292399 2021-04-09 21:50:08.986378 2021-04-09 21:50:08.986402
# 10672    13293802 2021-04-09 21:57:16.772498 2021-04-09 21:57:16.772520
# ...           ...                        ...                        ...
# 2146   2145249874 2021-04-09 12:50:28.784568 2021-04-09 12:50:28.784591
# 611    2146117575 2021-04-09 11:10:11.591959 2021-04-09 11:10:11.591987
# 5222   2146963759 2021-04-09 15:47:50.603961 2021-04-09 15:47:50.603983
# 4862   2146969821 2021-04-09 15:26:39.767134 2021-04-09 15:26:39.767167
# 5104   2146982601 2021-04-09 15:40:42.156865 2021-04-09 15:40:42.156892
#
#          city state     homeStatus  bedrooms  bathrooms   price  yearBuilt  \
# 9710   Denver    CO  RECENTLY_SOLD       4.0        3.0  597500     1943.0
# 9856   Denver    CO  RECENTLY_SOLD       3.0        1.0  410000     1920.0
# 9855   Denver    CO  RECENTLY_SOLD       2.0        1.0  375000     1906.0
# 10543  Denver    CO           SOLD       2.0        1.0  309900     1922.0
# 10672  Denver    CO           SOLD       2.0        1.0  360000     1942.0
# ...       ...   ...            ...       ...        ...     ...        ...
# 2146   Denver    CO  RECENTLY_SOLD       2.0        3.0  630000     2000.0
# 611    Denver    CO  RECENTLY_SOLD       2.0        2.0  501500     2007.0
# 5222   Denver    CO           SOLD       2.0        1.0  415000     1954.0
# 4862   Denver    CO           SOLD       2.0        3.0  570000     2006.0
# 5104   Denver    CO  RECENTLY_SOLD       2.0        2.0  450000     1998.0
#
#        ... monthlyHoaFee                    parentRegion propertyTaxRate  \
# 9710   ...           NaN               {'name': 'Regis'}            0.53
# 9856   ...           NaN               {'name': 'Regis'}            0.53
# 9855   ...           NaN               {'name': 'Regis'}            0.53
# 10543  ...           NaN               {'name': 'Regis'}            0.53
# 10672  ...           NaN               {'name': 'Regis'}            0.53
# ...    ...           ...                             ...             ...
# 2146   ...           NaN        {'name': 'Cherry Creek'}            0.53
# 611    ...           NaN        {'name': 'Capitol Hill'}            0.53
# 5222   ...           NaN       {'name': 'Cheesman Park'}            0.53
# 4862   ...           NaN      {'name': 'City Park West'}            0.53
# 5104   ...         300.0  {'name': 'North Capitol Hill'}            0.53
#
#                                               taxHistory  buildingId  \
# 9710   {'0': {'time': 1586487744980, 'value': 41192, ...        None
# 9856   {'0': {'time': 1586488228071, 'value': 25397, ...        None
# 9855   {'0': {'time': 1586488226714, 'value': 30774, ...        None
# 10543  {'0': {'time': 1586490608787, 'value': 29151, ...        None
# 10672  {'0': {'time': 1586491036339, 'value': 26798, ...        None
# ...                                                  ...         ...
# 2146                                                  {}  1001937453
# 611                                                   {}  2073262420
# 5222                                                  {}        None
# 4862                                                  {}        None
# 5104                                                  {}  2073263551
#
#       daysOnZillow isListedByOwner  pageViewCount favoriteCount  \
# 9710           239           False           17.0           0.0
# 9856           339           False           12.0           0.0
# 9855           337           False           21.0           0.0
# 10543          477           False            4.0           0.0
# 10672          932           False            1.0           0.0
# ...            ...             ...            ...           ...
# 2146            66           False           26.0           0.0
# 611             28           False           20.0           0.0
# 5222           387           False            4.0           0.0
# 4862          1092           False            0.0           0.0
# 5104           204           False            7.0           0.0
#
#        isIncomeRestricted
# 9710                 None
# 9856                 None
# 9855                 None
# 10543                None
# 10672                None
# ...                   ...
# 2146                 None
# 611                  None
# 5222                 None
# 4862                 None
# 5104                 None
#
# [10901 rows x 37 columns]

# %%
df = pd.read_sql_table('listings_query', connection)

# %%
df['DateAdded'].max()
# Out:
# Timestamp('2021-04-13 17:36:13.162133')

# %%
df_detail = pd.read_sql_table('listings_detailed', connection)

# %%
df_building = pd.read_sql_table("building_query", connection)
